# %%
import xarray as xr

# %%
ds = xr.open_dataset("2720_Sprof.nc")

# %%
#temperature
ds.TEMP.plot.pcolormesh()

# %%
#salinity
ds.PSAL.plot.pcolormesh()

# %%
#pressure
ds.PRES.plot.pcolormesh()

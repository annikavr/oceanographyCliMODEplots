# %%
import xarray as xr
file_list = ["2713_Sprof.nc", "2719_Sprof.nc", "2720_Sprof.nc", "2721_Sprof.nc", "2722_Sprof.nc", "2723_Sprof.nc", "2724_Sprof.nc", "2725_Sprof.nc", "2726_Sprof.nc"]
for file in file_list:
    ds = xr.open_dataset(file)
    ds.TEMP.plot.pcolormesh(add_colorbar= False)

# %%
for file in file_list:
    ds = xr.open_dataset(file)
    ds.PSAL.plot.pcolormesh(add_colorbar= False)

# %%
for file in file_list:
    ds = xr.open_dataset(file)
    ds.PRES.plot.pcolormesh(add_colorbar= False)

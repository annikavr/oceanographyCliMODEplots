# %%
# !pip install xarray

# %%
import xarray as xr

# %%
ds = xr.open_dataset("2719_Sprof.nc")
list(ds.data_vars)
# Out:
# ['DATA_TYPE',
#  'FORMAT_VERSION',
#  'HANDBOOK_VERSION',
#  'REFERENCE_DATE_TIME',
#  'DATE_CREATION',
#  'DATE_UPDATE',
#  'PLATFORM_NUMBER',
#  'PROJECT_NAME',
#  'PI_NAME',
#  'STATION_PARAMETERS',
#  'CYCLE_NUMBER',
#  'DIRECTION',
#  'DATA_CENTRE',
#  'PARAMETER_DATA_MODE',
#  'PLATFORM_TYPE',
#  'FLOAT_SERIAL_NO',
#  'FIRMWARE_VERSION',
#  'WMO_INST_TYPE',
#  'JULD',
#  'JULD_QC',
#  'JULD_LOCATION',
#  'LATITUDE',
#  'LONGITUDE',
#  'POSITION_QC',
#  'POSITIONING_SYSTEM',
#  'CONFIG_MISSION_NUMBER',
#  'PROFILE_PRES_QC',
#  'PROFILE_TEMP_QC',
#  'PROFILE_PSAL_QC',
#  'PROFILE_DOXY_QC',
#  'PRES',
#  'PRES_QC',
#  'PRES_ADJUSTED',
#  'PRES_ADJUSTED_QC',
#  'PRES_ADJUSTED_ERROR',
#  'TEMP',
#  'TEMP_QC',
#  'TEMP_ADJUSTED',
#  'TEMP_ADJUSTED_QC',
#  'TEMP_ADJUSTED_ERROR',
#  'PSAL',
#  'PSAL_QC',
#  'PSAL_ADJUSTED',
#  'PSAL_ADJUSTED_QC',
#  'PSAL_ADJUSTED_ERROR',
#  'DOXY',
#  'DOXY_QC',
#  'DOXY_ADJUSTED',
#  'DOXY_ADJUSTED_QC',
#  'DOXY_ADJUSTED_ERROR',
#  'PARAMETER',
# ...

# %%
ds.TEMP.plot.pcolormesh()

# %%
#2719 sprof nc, temperature plot graph

# %%
ds.PSAL.plot.pcolormesh()

# %%
#psalinity plot

# %%
ds.PRES.plot.pcolormesh()

# %%
#pressure plot

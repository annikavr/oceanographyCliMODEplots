# %%
# !pip install xarray

# %%
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.colors import PowerNorm
ds = xr.open_dataset("2721_Sprof.nc")
#temperature
ds.TEMP.plot.pcolormesh()
